# %% [markdown]
# # Ex. 5. Challenge (optional)
# ### Template provided by Christian Igel, 2020

# %%
# %tensorflow_version 2.x
import tensorflow as tf
import matplotlib.pyplot as plt 
import numpy as np
import pathlib
import os

print("TensorFlow version:", tf.__version__)

AUTOTUNE = tf.data.experimental.AUTOTUNE
# Out:
# TensorFlow version: 2.2.0

# %% [markdown]
# Download the data:

# %%
data_root="."
tf.keras.utils.get_file("GTSRB.zip",
                        "https://sid.erda.dk/share_redirect/EB0rrpZwuI",
                        cache_dir=data_root,
                        extract=True)
# Out:
# './datasets/GTSRB.zip'

# %% [markdown]
# The images are stored in subdirectories. The names of the subdirectories encode the class labels.

# %%
# Determine the number of training and test images
n_train = len(list(pathlib.Path(data_root).glob("datasets/GTSRB/train/*/*")))
n_test = len(list(pathlib.Path(data_root).glob("datasets/GTSRB/test/*/*")))

print("Number of training images:", n_train)
print("Number of test images:" ,n_test)
# Out:
# Number of training images: 39209
# Number of test images: 12630

# %% [markdown]
# Some basic constants:

# %%
no_classes = 43 
no_channels = 3  

# All images are initially resized to img_height x img_width
img_height  = 32  
img_width   = 32
# During training and testing the  images are cropped to img_height_crop x img_width_crop
img_height_crop = 28  
img_width_crop  = 28

batch_size = 128
steps_per_epoch = n_train // batch_size

# %% [markdown]
# Helper function for extracting the label information from the paths to the images and loading and preprocessing the images:

# %%
# Extract the label from the file path
def get_label(file_path):
  # convert the path to a list of path components
  parts = tf.strings.split(file_path, os.path.sep)
  # The second to last is the class-directory
  return tf.strings.to_number(parts[-2], tf.int32)

# Load image, convert it to floats, and resize it
def decode_img(img):
  # convert the compressed string to a 3D uint8 tensor
  img = tf.image.decode_png(img, channels=no_channels)
  # Use `convert_image_dtype` to convert to floats in the [0,1] range.
  img = tf.image.convert_image_dtype(img, tf.float32)
  # Resize the image to the desired size.
  return tf.image.resize(img, [img_width, img_height])

# Given the path and filename of an image, create the label and the input image
def process_path(file_path):
  label = get_label(file_path)
  # Load the raw data from the file as a string
  img = tf.io.read_file(file_path)
  img = decode_img(img)
  return img, label

# %% [markdown]
# Create data sets based on the files:

# %%
# Tell dataset the lists of files containing the trainig and test images, respectively
list_ds_train = tf.data.Dataset.list_files(data_root + "/datasets/GTSRB/train/*/*")
list_ds_test  = tf.data.Dataset.list_files(data_root + "/datasets/GTSRB/test/*/*", shuffle=False)  

# Tell dataset how to extract images and labels
labeled_ds_train = list_ds_train.map(process_path, num_parallel_calls=AUTOTUNE)
labeled_ds_test = list_ds_test.map(process_path, num_parallel_calls=AUTOTUNE)

# %% [markdown]
# Functions for data preprocessing/augmentation:

# %%
# Used for training data augmentation
def augment(image, label):
    # Take a random sub-image 28x28 from the input
    image = tf.image.random_crop(image, [img_height_crop, img_width_crop, no_channels])
    # Only for the defines labels, random flip the image
    image = tf.case([(tf.equal(label, 11), lambda: tf.image.random_flip_left_right(image)),
                     (tf.equal(label, 12), lambda: tf.image.random_flip_left_right(image)),
                     (tf.equal(label, 13), lambda: tf.image.random_flip_left_right(image)),
                     (tf.equal(label, 17), lambda: tf.image.random_flip_left_right(image)),
                     (tf.equal(label, 18), lambda: tf.image.random_flip_left_right(image)),
                     (tf.equal(label, 26), lambda: tf.image.random_flip_left_right(image)),
                     (tf.equal(label, 30), lambda: tf.image.random_flip_left_right(image)),
                     (tf.equal(label, 35), lambda: tf.image.random_flip_left_right(image))], default = lambda: image)
    # Change the brightness (sometimes brighter, sometimes darker)
    image = tf.image.random_brightness(image, max_delta=0.1) 
    # Change colors saturation (ADDED)
    image = tf.image.random_saturation(image, 0.5,2)
    # Change contrast (ADDED)
    image = tf.image.random_contrast(image, 0.7, 1.3)
    # Clip all values from 0 and 1, so that they are the values of a proper image
    image = tf.clip_by_value(image, 0., 1.)
    return image, label

# Used for testing/evaluation
def crop_center(image, label):
  image = tf.image.resize_with_crop_or_pad(image, img_height_crop, img_width_crop)
  return image, label

# Could be used for test time augementation
def crop_random(image, label):
  image = tf.image.random_crop(image, [img_height_crop, img_width_crop, no_channels])
  return image, label

# %% [markdown]
# We prepare the data for training and testing differently. For example, for training we use data augmentation.

# %%
def prepare_for_training(ds, cache=True, shuffle_buffer_size=1000):
  if cache:
    if isinstance(cache, str): 
      ds = ds.cache(cache) 
    else:
      ds = ds.cache()  
  # We shuffle the data after the caching
  ds = ds.shuffle(buffer_size=shuffle_buffer_size, reshuffle_each_iteration=True)
  # Repeat forever
  ds = ds.repeat()
  # Do data augmentation
  ds = ds.map(augment, num_parallel_calls=AUTOTUNE)
  # Partition in batches
  ds = ds.batch(batch_size)
  # Fetch batches in the background while the model training
  ds = ds.prefetch(buffer_size=AUTOTUNE)
  return ds

def prepare_for_evaluation(ds, shuffle_buffer_size=1000):
  # For normal evaluation, we look at the center of the image
  ds = ds.map(crop_center, num_parallel_calls=AUTOTUNE)
  # Partition in batches
  ds = ds.batch(batch_size)
  # Fetch batches in the background while the model training
  ds = ds.prefetch(buffer_size=AUTOTUNE)
  return ds

def prepare_for_augmented_evaluation(ds):
  ds = ds.map(crop_random, num_parallel_calls=AUTOTUNE)
  ds = ds.batch(batch_size)
  ds = ds.prefetch(buffer_size=AUTOTUNE)
  return ds

# Make training dataset 
train_ds = prepare_for_training(labeled_ds_train)

# Make test dataset 
test_ds = prepare_for_evaluation(labeled_ds_train)

# %% [markdown]
# Let's have a look at a random batch of images:

# %%
# Helper function for displaying images
def show_batch(image_batch, label_batch, nrows=6, ncols=6):
  plt.figure(figsize=(10,10))
  for n in range(nrows*ncols):
      ax = plt.subplot(nrows, ncols, n+1)
      if no_channels == 3:
        plt.imshow(image_batch[n])
      else:
        plt.imshow(image_batch[n].reshape([img_height_crop, img_width_crop]))
      plt.title('class:' + str(label_batch[n]))
      plt.axis('off')

# Get a batch of images and labels
image_batch, label_batch = next(iter(train_ds))

# Visualize images and labels
show_batch(image_batch.numpy(), label_batch.numpy())

# %% [markdown]
# Define a neural network model:

# %%
sd_init = 0.01  
sd_mean = 0.05

model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(32, (5, 5), activation=None,  
                           input_shape=(img_width_crop, img_height_crop, no_channels),
                           bias_initializer=tf.initializers.TruncatedNormal(mean=sd_mean, stddev=sd_init)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.ELU(),
    tf.keras.layers.MaxPooling2D(pool_size=(2,2)),
    tf.keras.layers.Dropout(0.25, seed=seed_value),
    tf.keras.layers.Conv2D(64, (5, 5), activation=None, 
                           bias_initializer=tf.initializers.TruncatedNormal(mean=sd_mean, stddev=sd_init)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.ELU(),
    tf.keras.layers.MaxPooling2D(pool_size=(2,2)),
    tf.keras.layers.Dropout(0.5, seed=seed_value),
    tf.keras.layers.Conv2D(128, (3, 3), activation=None, 
                           bias_initializer=tf.initializers.TruncatedNormal(mean=sd_mean, stddev=sd_init)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.ELU(),
    tf.keras.layers.MaxPooling2D(pool_size=(2,2)),
    tf.keras.layers.Dropout(0.5, seed=seed_value),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(no_classes, activation='softmax')])
 
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 24, 24, 32)        2432
# _________________________________________________________________
# batch_normalization (BatchNo (None, 24, 24, 32)        128
# _________________________________________________________________
# elu (ELU)                    (None, 24, 24, 32)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 12, 12, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 12, 12, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 8, 8, 64)          51264
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 8, 8, 64)          256
# _________________________________________________________________
# elu_1 (ELU)                  (None, 8, 8, 64)          0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4, 4, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 2, 2, 128)         73856
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 2, 2, 128)         512
# _________________________________________________________________
# elu_2 (ELU)                  (None, 2, 2, 128)         0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 1, 1, 128)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1, 1, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 43)                5547
# =================================================================
# Total params: 133,995
# Trainable params: 133,547
# Non-trainable params: 448
# _________________________________________________________________

# %% [markdown]
# Define optimizer and compile the model:

# %%
opt = tf.keras.optimizers.Adam(learning_rate=0.05, epsilon=0.1)
model.compile(loss='sparse_categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

# %% [markdown]
# Do the learning:

# %%
# Train the model
import time
start = time.time()

history = model.fit(train_ds, epochs=1200, steps_per_epoch=steps_per_epoch)

print("Training took", (time.time() - start)/60, "minutes.")
# Out:
# COMET INFO: Ignoring automatic log_parameter('verbose') because 'keras:verbose' is in COMET_LOGGING_PARAMETERS_IGNORE
# Epoch 1/1200
# 306/306 [==============================] - 19s 61ms/step - loss: 2.3415 - accuracy: 0.3644
# Epoch 2/1200
# 306/306 [==============================] - 6s 20ms/step - loss: 1.0285 - accuracy: 0.6934
# Epoch 3/1200
# 306/306 [==============================] - 6s 20ms/step - loss: 0.6400 - accuracy: 0.8148
# Epoch 4/1200
# 306/306 [==============================] - 6s 20ms/step - loss: 0.4913 - accuracy: 0.8596
# Epoch 5/1200
# 306/306 [==============================] - 6s 20ms/step - loss: 0.3960 - accuracy: 0.8881
# Epoch 6/1200
# 306/306 [==============================] - 6s 20ms/step - loss: 0.3495 - accuracy: 0.9004
# Epoch 7/1200
# 306/306 [==============================] - 6s 20ms/step - loss: 0.3087 - accuracy: 0.9122
# Epoch 8/1200
# 306/306 [==============================] - 6s 20ms/step - loss: 0.2820 - accuracy: 0.9208
# Epoch 9/1200
# 306/306 [==============================] - 6s 20ms/step - loss: 0.2665 - accuracy: 0.9247
# Epoch 10/1200
# 306/306 [==============================] - 6s 19ms/step - loss: 0
# 306/306 [==============================] - 7s 22ms/step - loss: 0.0384 - accuracy: 0.9882
# Epoch 1181/1200
# 306/306 [==============================] - 7s 21ms/step - loss: 0.0443 - accuracy: 0.9877
# Epoch 1182/1200
# 306/306 [==============================] - 7s 21ms/step - loss: 0.0382 - accuracy: 0.9893
# Epoch 1183/1200
# 306/306 [==============================] - 6s 21ms/step - loss: 0.0420 - accuracy: 0.9875
# Epoch 1184/1200
# 306/306 [==============================] - 7s 21ms/step - loss: 0.0439 - accuracy: 0.9877
# Epoch 1185/1200
# 306/306 [==============================] - 7s 22ms/step - loss: 0.0413 - accuracy: 0.9876
# Epoch 1186/1200
# 306/306 [==============================] - 6s 21ms/step - loss: 0.0398 - accuracy: 0.9882
# Epoch 1187/1200
# 306/306 [==============================] - 6s 21ms/step - loss: 0.0402 - accuracy: 0.9884
# Epoch 1188/1200
# 306/306 [==============================] - 7s 23ms/step - loss: 0.0389 - accuracy: 0.9889
# Epoch 1189/1200
# 306/306 [==============================] - 7s 23ms/step - loss: 0.0397 - accuracy: 0.9887
# Epoch 1190/1200
# 306/306 [==============================] - 7s 21ms/step - loss: 0.0422 - accuracy: 0.9882
# Epoch 1191/1200
# 306/306 [==============================] - 7s 22ms/step - loss: 0.0408 - accuracy: 0.9885
# Epoch 1192/1200
# 306/306 [==============================] - 7s 22ms/step - loss: 0.0396 - accuracy: 0.9885
# Epoch 1193/1200
# 306/306 [==============================] - 7s 22ms/step - loss: 0.0399 - accuracy: 0.9885
# Epoch 1194/1200
# 306/306 [==============================] - 7s 23ms/step - loss: 0.0415 - accuracy: 0.9879
# Epoch 1195/1200
# 306/306 [==============================] - 7s 22ms/step - loss: 0.0432 - accuracy: 0.9878
# Epoch 1196/1200
# 306/306 [==============================] - 7s 21ms/step - loss: 0.0416 - accuracy: 0.9878
# Epoch 1197/1200
# 306/306 [==============================] - 7s 22ms/step - loss: 0.0395 - accuracy: 0.9885
# Epoch 1198/1200
# 306/306 [==============================] - 6s 21ms/step - loss: 0.0383 - accuracy: 0.9890
# Epoch 1199/1200
# 306/306 [==============================] - 6s 21ms/step - loss: 0.0388 - accuracy: 0.9886
# Epoch 1200/1200
# 306/306 [==============================] - 7s 22ms/step - loss: 0.0418 - accuracy: 0.9881
# Training took 122.48751882314681 minutes.

# %% [markdown]
# Let's evaluate the model:

# %%
eval_train_ds = prepare_for_evaluation(labeled_ds_train)
eval_test_ds = prepare_for_evaluation(labeled_ds_test)
train_results = model.evaluate(eval_train_ds)
print('Train loss, train acc:', train_results)
test_results = model.evaluate(eval_test_ds)
print('Test loss, test acc:', test_results)

train_acc = train_results[1]
test_acc = test_results[1]
experiment.log_metric("Train accuracy", train_acc)
experiment.log_metric("Test accuracy", test_acc)
# Out:
# 307/307 [==============================] - 16s 51ms/step - loss: 6.2056e-04 - accuracy: 0.9999
# Train loss, train acc: [0.00062055594753474, 0.9999234676361084]
# 99/99 [==============================] - 5s 53ms/step - loss: 0.0351 - accuracy: 0.9911
# Test loss, test acc: [0.03510139882564545, 0.9911321997642517]
